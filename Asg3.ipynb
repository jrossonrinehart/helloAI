# %% [markdown]
# <a href="https://colab.research.google.com/github/jrossonrinehart/helloAI/blob/main/Asg3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://blog.infuseai.io/run-a-full-tty-terminal-in-google-colab-without-colab-pro-2759b9f8a74a
# xterm may be helpful for speeding up some of the parts of this assignment ... see in class instruction on usage
#!pip install colab-xterm
#%load_ext colabxterm
# !git clone "https://github.com/kartoone/nn3"
# !git pull
# Out:
# Cloning into 'nn3'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 156 (delta 26), reused 17 (delta 8), pack-reused 109
# Receiving objects: 100% (156/156), 94.35 MiB | 18.24 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Updating files: 100% (106/106), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd nn3/src
# Out:
# /content/nn3/src

# %%
from network import Network
import mnist_loader
import numpy as np
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = Network([784, 30, 10])
print(np.shape(net.biases))
print(net.biases)
# Out:
# (2,)
# [array([[ 0.47933376],
#        [-0.08373127],
#        [-0.11775935],
#        [-0.89859973],
#        [-1.78393701],
#        [ 0.27766186],
#        [ 0.88829476],
#        [-0.42437324],
#        [ 0.22357693],
#        [-1.12991001],
#        [-0.92654609],
#        [ 2.52746455],
#        [-0.15427925],
#        [-0.85699106],
#        [ 0.98205841],
#        [-0.46174179],
#        [ 0.38624758],
#        [ 0.4889782 ],
#        [-1.12629859],
#        [ 1.3496519 ],
#        [-0.14689017],
#        [ 0.23920477],
#        [ 0.28244156],
#        [ 1.48191039],
#        [ 0.10439315],
#        [ 0.0518976 ],
#        [-1.48343629],
#        [ 0.07548702],
#        [ 0.81053449],
#        [ 0.06564832]]), array([[ 0.79542257],
#        [ 0.71337992],
#        [ 1.19626048],
#        [ 1.75334388],
#        [ 1.10112705],
#        [ 0.03723345],
#        [ 0.91886974],
#        [-0.34785189],
#        [-0.56160439],
#        [ 0.11472053]])]
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
import numpy as np

# finds the image that the network has the hardest time classifying
def findTroublesomeImage(test_data, net):
  worsti = -1
  worsta = 1.0
  for i,(x,y) in enumerate(test_data):
    a = net.feedforward(x)
    if np.max(a)<worsta:
      worsta = np.max(a)
      worsti = i
  print(worsta)
  print(worsti)
  return worsti

# %% [markdown]
# #Part 1 - Exploring different configurations
#  run neural networks models with these configurations:
#
#  One hidden layer with 15 neurons
#  One hidden layer with 30 neurons
#  One hidden layer with 100 neurons
#  Two hidden layers with 15 neurons each
#  Two hidden layers with 30 neurons each
#  Two hidden layers with 100 neurons each (caution, this will take a
#  LONG time to train)

# %%
  from network import Network
  import mnist_loader
  import time

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = [[784,15,10], [784,30,10], [784,100,10], [784, 15, 15, 10], [784,30,30,10], [784,100,100,10]] # ADD THE REMAINING CONFIGS HERE!!!!training_times = []
  training_times = []
  accuracies = []
  for config in configs:
    print(config)
    start = time.time()
    net = Network(config)
    accuracies.append(net.SGD(training_data[0:1000], 30, 10, 3.0, test_data=test_data[0:1000]))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:1000], net)
    import matplotlib.pyplot as plt
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# Out:
# [784, 15, 10]
# Epoch 0: starting...training completed in 1.02s...measuring accuracy...230 / 1000 in 0.34s
# Epoch 1: starting...training completed in 1.44s...measuring accuracy...323 / 1000 in 0.27s
# Epoch 2: starting...training completed in 0.68s...measuring accuracy...396 / 1000 in 0.33s
# Epoch 3: starting...training completed in 0.96s...measuring accuracy...464 / 1000 in 0.31s
# Epoch 4: starting...training completed in 1.16s...measuring accuracy...560 / 1000 in 0.32s
# Epoch 5: starting...training completed in 1.8s...measuring accuracy...599 / 1000 in 0.34s
# Epoch 6: starting...training completed in 0.88s...measuring accuracy...642 / 1000 in 0.49s
# Epoch 7: starting...training completed in 1.73s...measuring accuracy...642 / 1000 in 0.24s
# Epoch 8: starting...training completed in 1.02s...measuring accuracy...670 / 1000 in 0.23s
# Epoch 9: starting...training completed in 1.08s...measuring accuracy...692 / 1000 in 0.12s
# Epoch 10: starting...training completed in 0.38s...measuring accuracy...647 / 1000 in 0.1s
# Epoch 11: starting...training completed in 0.39s...measuring accuracy...681 / 1000 in 0.08s
# Epoch 12: starting...training completed in 0.42s...measuring accuracy...683 / 1000 in 0.1s
# Epoch 13: starting...training completed in 0.49s...measuring accuracy...683 / 1000 in 0.09s
# Epoch 14: starting...training completed in 0.45s...measuring accuracy...690 / 1000 in 0.13s
# Epoch 15: starting...training completed in 0.48s...measuring accuracy...697 / 1000 in 0.16s
# Epoch 16: starting...training completed in 0.54s...measuring accuracy...705 / 1000 in 0.16s
# Epoch 17: starting...training completed in 0.48s...measuring accuracy...707 / 1000 in 0.12s
# Epoch 18: starting...training completed in 0.4s...measuring accuracy...714 / 1000 in 0.12s
# Epoch 19: starting...training completed in 0.32s...measuring accuracy...719 / 1000 in 0.08s
# Epoch 20: starting...training completed in 0.43s...measuring accuracy...707 / 1000 in 0.14s
# Epoch 21: starting...training completed in 0.52s...measuring accuracy...715 / 1000 in 0.11s
# Epoch 22: starting...training completed in 0.44s...measuring accuracy...723 / 1000 in 0.1s
# Epoch 23: starting...training completed in 0.41s...measuring accuracy...723 / 1000 in 0.08s
# Epoch 24: starting...training completed in 0.4s...measuring accuracy...720 / 1000 in 0.12s
# Epoch 25: starting...training completed in 0.55s...measuring accuracy...713 / 1000 in 0.12s
# Epoch 26: starting...training completed in 0.6s...measuring accuracy...725 / 1000 in 0.13s
# Epoch 27: starting...training completed in 0.59s...measuring accuracy...717 / 1000 in 0.13s
# Epoch 28: starting...training completed in 0.53s...measuring accuracy...724 / 1000 in 0.1s
# Epoch 29: starting...training completed in 0.44s...measuring accuracy...726 / 1000 in 0.08s
# 26.35649847984314
# 0.040942315476136394
# 241
# [784, 30, 10]
# Epoch 0: starting...training completed in 0.52s...measuring accuracy...216 / 1000 in 0.1s
# Epoch 1: starting...training completed in 0.26s...measuring accuracy...441 / 1000 in 0.06s
# Epoch 2: starting...training completed in 0.2s...measuring accuracy...494 / 1000 in 0.04s
# Epoch 3: starting...training completed in 0.24s...measuring accuracy...541 / 1000 in 0.06s
# Epoch 4: starting...training completed in 0.21s...measuring accuracy...585 / 1000 in 0.06s
# Epoch 5: starting...training completed in 0.25s...measuring accuracy...613 / 1000 in 0.04s
# Epoch 6: starting...training completed in 0.2s...measuring accuracy...639 / 1000 in 0.05s
# Epoch 7: starting...training completed in 0.21s...measuring accuracy...645 / 1000 in 0.04s
# Epoch 8: starting...training completed in 0.23s...measuring accuracy...655 / 1000 in 0.04s
# Epoch 9: starting...training completed in 0.22s...measuring accuracy...661 / 1000 in 0.04s
# Epoch 10: starting...training completed in 0.2s...measuring accuracy...692 / 1000 in 0.04s
# Epoch 11: starting...training completed in 0.22s...measuring accuracy...697 / 1000 in 0.04s
# Epoch 12: starting...training completed in 0.2s...measuring accuracy...694 / 1000 in 0.04s
# Epoch 13: starting...training completed in 0.23s...measuring accuracy...698 / 1000 in 0.04s
# Epoch 14: starting...training completed in 0.22s...measuring accuracy...703 / 1000 in 0.04s
# Epoch 15: starting...training completed in 0.21s...measuring accuracy...706 / 1000 in 0.04s
# Epoch 16: starting...training completed in 0.22s...measuring accuracy...704 / 1000 in 0.04s
# Epoch 17: starting...training completed in 0.23s...measuring accuracy...713 / 1000 in 0.04s
# Epoch 18: starting...training completed in 0.2s...measuring accuracy...715 / 1000 in 0.04s
# Epoch 19: starting...training completed in 0.22s...measuring accuracy...707 / 1000 in 0.04s
# Epoch 20: starting...training completed in 0.2s...measuring accuracy...712 / 1000 in 0.04s
# Epoch 21: starting...training completed in 0.19s...measuring accuracy...717 / 1000 in 0.06s
# Epoch 22: starting...training completed in 0.2s...measuring accuracy...720 / 1000 in 0.04s
# Epoch 23: starting...training completed in 0.21s...measuring accuracy...718 / 1000 in 0.04s
# Epoch 24: starting...training completed in 0.21s...measuring accuracy...721 / 1000 in 0.04s
# Epoch 25: starting...training completed in 0.2s...measuring accuracy...721 / 1000 in 0.06s
# Epoch 26: starting...training completed in 0.21s...measuring accuracy...729 / 1000 in 0.04s
# Epoch 27: starting...training completed in 0.21s...measuring accuracy...729 / 1000 in 0.06s
# Epoch 28: starting...training completed in 0.2s...measuring accuracy...728 / 1000 in 0.04s
# Epoch 29: starting...training completed in 0.2s...measuring accuracy...736 / 1000 in 0.06s
# 8.13852596282959
# 0.0115083041819064
# 436
# [784, 100, 10]
# Epoch 0: starting...training completed in 0.49s...measuring accuracy...218 / 1000 in 0.05s
# Epoch 1: starting...training completed in 0.55s...measuring accuracy...297 / 1000 in 0.06s
# Epoch 2: starting...training completed in 0.51s...measuring accuracy...379 / 1000 in 0.06s
# Epoch 3: starting...training completed in 0.53s...measuring accuracy...407 / 1000 in 0.06s
# Epoch 4: starting...training completed in 1.14s...measuring accuracy...435 / 1000 in 0.11s
# Epoch 5: starting...training completed in 1.05s...measuring accuracy...489 / 1000 in 0.11s
# Epoch 6: starting...training completed in 1.21s...measuring accuracy...498 / 1000 in 0.08s
# Epoch 7: starting...training completed in 0.63s...measuring accuracy...515 / 1000 in 0.06s
# Epoch 8: starting...training completed in 0.63s...measuring accuracy...527 / 1000 in 0.07s
# Epoch 9: starting...training completed in 0.56s...measuring accuracy...536 / 1000 in 0.06s
# Epoch 10: starting...training completed in 0.55s...measuring accuracy...548 / 1000 in 0.06s
# Epoch 11: starting...training completed in 0.55s...measuring accuracy...551 / 1000 in 0.06s
# Epoch 12: starting...training completed in 0.52s...measuring accuracy...554 / 1000 in 0.06s
# Epoch 13: starting...training completed in 0.52s...measuring accuracy...567 / 1000 in 0.06s
# Epoch 14: starting...training completed in 0.52s...measuring accuracy...571 / 1000 in 0.06s
# Epoch 15: starting...training completed in 0.59s...measuring accuracy...575 / 1000 in 0.06s
# Epoch 16: starting...training completed in 0.5s...measuring accuracy...582 / 1000 in 0.06s
# Epoch 17: starting...training completed in 0.53s...measuring accuracy...585 / 1000 in 0.06s
# Epoch 18: starting...training completed in 0.51s...measuring accuracy...587 / 1000 in 0.08s
# Epoch 19: starting...training completed in 0.49s...measuring accuracy...586 / 1000 in 0.06s
# Epoch 20: starting...training completed in 0.53s...measuring accuracy...592 / 1000 in 0.06s
# Epoch 21: starting...training completed in 0.48s...measuring accuracy...588 / 1000 in 0.06s
# Epoch 22: starting...training completed in 0.53s...measuring accuracy...586 / 1000 in 0.05s
# Epoch 23: starting...training completed in 0.85s...measuring accuracy...593 / 1000 in 0.14s
# Epoch 24: starting...training completed in 1.08s...measuring accuracy...591 / 1000 in 0.16s
# Epoch 25: starting...training completed in 1.31s...measuring accuracy...588 / 1000 in 0.13s
# Epoch 26: starting...training completed in 0.54s...measuring accuracy...595 / 1000 in 0.06s
# Epoch 27: starting...training completed in 0.48s...measuring accuracy...607 / 1000 in 0.06s
# Epoch 28: starting...training completed in 0.51s...measuring accuracy...624 / 1000 in 0.06s
# Epoch 29: starting...training completed in 0.57s...measuring accuracy...622 / 1000 in 0.08s
# 21.66050934791565
# 0.0007606839224163036
# 176
# [784, 15, 15, 10]
# Epoch 0: starting...training completed in 0.2s...measuring accuracy...327 / 1000 in 0.06s
# Epoch 1: starting...training completed in 0.19s...measuring accuracy...423 / 1000 in 0.05s
# Epoch 2: starting...training completed in 0.2s...measuring accuracy...501 / 1000 in 0.08s
# Epoch 3: starting...training completed in 0.19s...measuring accuracy...533 / 1000 in 0.05s
# Epoch 4: starting...training completed in 0.18s...measuring accuracy...574 / 1000 in 0.06s
# Epoch 5: starting...training completed in 0.19s...measuring accuracy...614 / 1000 in 0.05s
# Epoch 6: starting...training completed in 0.2s...measuring accuracy...643 / 1000 in 0.09s
# Epoch 7: starting...training completed in 0.22s...measuring accuracy...663 / 1000 in 0.05s
# Epoch 8: starting...training completed in 0.2s...measuring accuracy...664 / 1000 in 0.06s
# Epoch 9: starting...training completed in 0.21s...measuring accuracy...657 / 1000 in 0.05s
# Epoch 10: starting...training completed in 0.2s...measuring accuracy...707 / 1000 in 0.07s
# Epoch 11: starting...training completed in 0.19s...measuring accuracy...692 / 1000 in 0.05s
# Epoch 12: starting...training completed in 0.21s...measuring accuracy...723 / 1000 in 0.05s
# Epoch 13: starting...training completed in 0.2s...measuring accuracy...718 / 1000 in 0.05s
# Epoch 14: starting...training completed in 0.2s...measuring accuracy...743 / 1000 in 0.07s
# Epoch 15: starting...training completed in 0.21s...measuring accuracy...736 / 1000 in 0.05s
# Epoch 16: starting...training completed in 0.22s...measuring accuracy...716 / 1000 in 0.05s
# Epoch 17: starting...training completed in 0.2s...measuring accuracy...744 / 1000 in 0.05s
# Epoch 18: starting...training completed in 0.25s...measuring accuracy...747 / 1000 in 0.05s
# Epoch 19: starting...training completed in 0.22s...measuring accuracy...742 / 1000 in 0.05s
# Epoch 20: starting...training completed in 0.25s...measuring accuracy...756 / 1000 in 0.05s
# Epoch 21: starting...training completed in 0.21s...measuring accuracy...756 / 1000 in 0.05s
# Epoch 22: starting...training completed in 0.24s...measuring accuracy...754 / 1000 in 0.05s
# Epoch 23: starting...training completed in 0.2s...measuring accuracy...744 / 1000 in 0.05s
# Epoch 24: starting...training completed in 0.21s...measuring accuracy...747 / 1000 in 0.06s
# Epoch 25: starting...training completed in 0.21s...measuring accuracy...765 / 1000 in 0.06s
# Epoch 26: starting...training completed in 0.26s...measuring accuracy...762 / 1000 in 0.05s
# Epoch 27: starting...training completed in 0.22s...measuring accuracy...766 / 1000 in 0.06s
# Epoch 28: starting...training completed in 0.46s...measuring accuracy...760 / 1000 in 0.15s
# Epoch 29: starting...training completed in 0.54s...measuring accuracy...750 / 1000 in 0.11s
# 8.67698621749878
# 0.023183231338585866
# 18
# [784, 30, 30, 10]
# Epoch 0: starting...training completed in 0.63s...measuring accuracy...228 / 1000 in 0.14s
# Epoch 1: starting...training completed in 0.6s...measuring accuracy...309 / 1000 in 0.12s
# Epoch 2: starting...training completed in 0.54s...measuring accuracy...418 / 1000 in 0.06s
# Epoch 3: starting...training completed in 0.28s...measuring accuracy...582 / 1000 in 0.06s
# Epoch 4: starting...training completed in 0.27s...measuring accuracy...643 / 1000 in 0.05s
# Epoch 5: starting...training completed in 0.35s...measuring accuracy...663 / 1000 in 0.06s
# Epoch 6: starting...training completed in 0.27s...measuring accuracy...667 / 1000 in 0.06s
# Epoch 7: starting...training completed in 0.26s...measuring accuracy...693 / 1000 in 0.07s
# Epoch 8: starting...training completed in 0.29s...measuring accuracy...683 / 1000 in 0.06s
# Epoch 9: starting...training completed in 0.26s...measuring accuracy...698 / 1000 in 0.05s
# Epoch 10: starting...training completed in 0.24s...measuring accuracy...696 / 1000 in 0.05s
# Epoch 11: starting...training completed in 0.26s...measuring accuracy...705 / 1000 in 0.05s
# Epoch 12: starting...training completed in 0.27s...measuring accuracy...706 / 1000 in 0.06s
# Epoch 13: starting...training completed in 0.25s...measuring accuracy...718 / 1000 in 0.05s
# Epoch 14: starting...training completed in 0.26s...measuring accuracy...711 / 1000 in 0.1s
# Epoch 15: starting...training completed in 0.27s...measuring accuracy...713 / 1000 in 0.06s
# Epoch 16: starting...training completed in 0.24s...measuring accuracy...725 / 1000 in 0.05s
# Epoch 17: starting...training completed in 0.25s...measuring accuracy...725 / 1000 in 0.05s
# Epoch 18: starting...training completed in 0.28s...measuring accuracy...713 / 1000 in 0.05s
# Epoch 19: starting...training completed in 0.25s...measuring accuracy...726 / 1000 in 0.05s
# Epoch 20: starting...training completed in 0.26s...measuring accuracy...734 / 1000 in 0.05s
# Epoch 21: starting...training completed in 0.29s...measuring accuracy...735 / 1000 in 0.06s
# Epoch 22: starting...training completed in 0.29s...measuring accuracy...737 / 1000 in 0.05s
# Epoch 23: starting...training completed in 0.25s...measuring accuracy...742 / 1000 in 0.05s
# Epoch 24: starting...training completed in 0.32s...measuring accuracy...729 / 1000 in 0.05s
# Epoch 25: starting...training completed in 0.25s...measuring accuracy...731 / 1000 in 0.06s
# Epoch 26: starting...training completed in 0.24s...measuring accuracy...733 / 1000 in 0.05s
# Epoch 27: starting...training completed in 0.25s...measuring accuracy...742 / 1000 in 0.08s
# Epoch 28: starting...training completed in 0.29s...measuring accuracy...733 / 1000 in 0.05s
# Epoch 29: starting...training completed in 0.29s...measuring accuracy...737 / 1000 in 0.05s
# 10.92778491973877
# 0.033069856845502205
# 230
# [784, 100, 100, 10]
# Epoch 0: starting...training completed in 0.67s...measuring accuracy...147 / 1000 in 0.07s
# Epoch 1: starting...training completed in 1.5s...measuring accuracy...326 / 1000 in 0.14s
# Epoch 2: starting...training completed in 1.32s...measuring accuracy...360 / 1000 in 0.16s
# Epoch 3: starting...training completed in 0.71s...measuring accuracy...424 / 1000 in 0.09s
# Epoch 4: starting...training completed in 0.61s...measuring accuracy...418 / 1000 in 0.09s
# Epoch 5: starting...training completed in 0.58s...measuring accuracy...474 / 1000 in 0.07s
# Epoch 6: starting...training completed in 0.61s...measuring accuracy...490 / 1000 in 0.07s
# Epoch 7: starting...training completed in 0.66s...measuring accuracy...516 / 1000 in 0.09s
# Epoch 8: starting...training completed in 0.6s...measuring accuracy...565 / 1000 in 0.07s
# Epoch 9: starting...training completed in 0.59s...measuring accuracy...576 / 1000 in 0.07s
# Epoch 10: starting...training completed in 0.61s...measuring accuracy...588 / 1000 in 0.1s
# Epoch 11: starting...training completed in 0.67s...measuring accuracy...606 / 1000 in 0.07s
# Epoch 12: starting...training completed in 0.66s...measuring accuracy...590 / 1000 in 0.07s
# Epoch 13: starting...training completed in 0.67s...measuring accuracy...602 / 1000 in 0.09s
# Epoch 14: starting...training completed in 0.74s...measuring accuracy...603 / 1000 in 0.1s
# Epoch 15: starting...training completed in 0.63s...measuring accuracy...629 / 1000 in 0.07s
# Epoch 16: starting...training completed in 0.63s...measuring accuracy...639 / 1000 in 0.07s
# Epoch 17: starting...training completed in 1.42s...measuring accuracy...626 / 1000 in 0.14s
# Epoch 18: starting...training completed in 1.62s...measuring accuracy...636 / 1000 in 0.16s
# Epoch 19: starting...training completed in 0.74s...measuring accuracy...636 / 1000 in 0.09s
# Epoch 20: starting...training completed in 0.57s...measuring accuracy...643 / 1000 in 0.07s
# Epoch 21: starting...training completed in 0.6s...measuring accuracy...646 / 1000 in 0.07s
# Epoch 22: starting...training completed in 0.59s...measuring accuracy...655 / 1000 in 0.07s
# Epoch 23: starting...training completed in 0.68s...measuring accuracy...652 / 1000 in 0.09s
# Epoch 24: starting...training completed in 0.6s...measuring accuracy...655 / 1000 in 0.07s
# Epoch 25: starting...training completed in 0.66s...measuring accuracy...650 / 1000 in 0.07s
# Epoch 26: starting...training completed in 0.71s...measuring accuracy...653 / 1000 in 0.07s
# Epoch 27: starting...training completed in 0.62s...measuring accuracy...691 / 1000 in 0.07s
# Epoch 28: starting...training completed in 0.64s...measuring accuracy...703 / 1000 in 0.08s
# Epoch 29: starting...training completed in 0.72s...measuring accuracy...716 / 1000 in 0.08s
# 25.269490957260132
# 0.0012392212651423863
# 252

# %%
print(configs)
print(training_times)
print(accuracies)
# Out:
# [[784, 15, 10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], [784, 30, 30, 10], [784, 100, 100, 10]]
# [26.35649847984314, 8.13852596282959, 21.66050934791565, 8.67698621749878, 10.92778491973877, 25.269490957260132]
# [726, 736, 622, 750, 737, 716]

# %% [markdown]
# #Part 2

# %%
  from network2 import Network
  from network2 import QuadraticCost
  import mnist_loader
  import time
  import matplotlib.pyplot as plt

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = []
  for epochs in [15, 30, 45, 100]:
    for batchsize in [5, 10, 20, 100]:
      for learningrate in [0.1, 0.5, 1.0, 3.0, 5.0]:
        configs.append([epochs, batchsize, learningrate])

  # only train on small slice (start with 100 ... but then once you have your graphs working ... bump it up to 1000 and re-run)
  training_data = training_data[0:100]
  test_data = test_data[0:100]

  training_times = []
  accuracies = []  
  # note that this will be a GIANT list of training times for each config plus the two cost functions. [time1, time2, time3, time4] ... 
  #  time1 and time2 are both associated with the single hidden layer network and differ in the cost function (time1 - crossentropy, time2-quadratic)
  #  time3 and time4 are both associated with the dual hidden layer network and differ in the cost function (time3 - crossentropy, time4-quadratic)
  # NOTE: once you are happy with the results ... remove the 0:1000 and use the complete training data
  for config in configs:
    print(config, "single hidden layer plus cross-entropy")
    start = time.time()
    net1 = Network([784,15,10]) # cross-entropy cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "single hidden layer plus quadratic")
    start = time.time()
    net1 = Network([784, 15, 10],cost=QuadraticCost) # quadratic cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    # repeat for the two layer network
    print(config, "dual hidden layers plus cross-entropy")
    start = time.time()
    net2 = Network([784,30,15,10])
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "dual hidden layers plus quadratic")
    start = time.time()
    net2 = Network([784,30,15, 10],cost=QuadraticCost)
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# Out:
# [15, 5, 0.1] single hidden layer plus cross-entropy
# 0.5530755519866943
# 0.1536337758484985
# 17
# [15, 5, 0.1] single hidden layer plus quadratic
# 0.716522216796875
# 0.12981449244740198
# 79
# [15, 5, 0.1] dual hidden layers plus cross-entropy
# 1.2640798091888428
# 0.122810539006493
# 33
# [15, 5, 0.1] dual hidden layers plus quadratic
# 0.5291314125061035
# 0.13104952313835386
# 79
# [15, 5, 0.5] single hidden layer plus cross-entropy
# 0.26241397857666016
# 0.0868528893022125
# 44
# [15, 5, 0.5] single hidden layer plus quadratic
# 0.35259556770324707
# 0.1627965113043131
# 11
# [15, 5, 0.5] dual hidden layers plus cross-entropy
# 0.46802282333374023
# 0.09190204356667789
# 22
# [15, 5, 0.5] dual hidden layers plus quadratic
# 0.4821352958679199
# 0.12674430863112962
# 93
# [15, 5, 1.0] single hidden layer plus cross-entropy
# 0.25005626678466797
# 0.11319496622076915
# 23
# [15, 5, 1.0] single hidden layer plus quadratic
# 0.3052823543548584
# 0.14154445701848653
# 23
# [15, 5, 1.0] dual hidden layers plus cross-entropy
# 0.4949791431427002
# 0.11583949258096193
# 45
# [15, 5, 1.0] dual hidden layers plus quadratic
# 0.5144631862640381
# 0.14726814939625013
# 18
# [15, 5, 3.0] single hidden layer plus cross-entropy
# 0.2810075283050537
# 0.22264500482807725
# 16
# [15, 5, 3.0] single hidden layer plus quadratic
# 0.28668785095214844
# 0.11370232187852772
# 97
# [15, 5, 3.0] dual hidden layers plus cross-entropy
# 0.5136191844940186
# 0.10333580816006692
# 15
# [15, 5, 3.0] dual hidden layers plus quadratic
# 0.5003936290740967
# 0.10574934802713438
# 43
# [15, 5, 5.0] single hidden layer plus cross-entropy
# 0.28267431259155273
# 0.31832003771941153
# 69
# [15, 5, 5.0] single hidden layer plus quadratic
# 0.3007798194885254
# 0.19478069568446887
# 47
# [15, 5, 5.0] dual hidden layers plus cross-entropy
# 0.4660530090332031
# 0.5401925693139737
# 25
# [15, 5, 5.0] dual hidden layers plus quadratic
# 0.49892354011535645
# 0.1744299580346942
# 34
# [15, 10, 0.1] single hidden layer plus cross-entropy
# 0.6734499931335449
# 0.12268847494998818
# 95
# [15, 10, 0.1] single hidden layer plus quadratic
# 0.6452977657318115
# 0.12096665172046406
# 79
# [15, 10, 0.1] dual hidden layers plus cross-entropy
# 1.1595244407653809
# 0.13400282749779907
# 93
# [15, 10, 0.1] dual hidden layers plus quadratic
# 0.5767245292663574
# 0.13764704859534557
# 20
# [15, 10, 0.5] single hidden layer plus cross-entropy
# 0.29096508026123047
# 0.06421562299034175
# 11
# [15, 10, 0.5] single hidden layer plus quadratic
# 0.3306734561920166
# 0.13539783125914845
# 68
# [15, 10, 0.5] dual hidden layers plus cross-entropy
# 0.4609661102294922
# 0.11137708654874956
# 97
# [15, 10, 0.5] dual hidden layers plus quadratic
# 0.5054190158843994
# 0.13183632976586873
# 48
# [15, 10, 1.0] single hidden layer plus cross-entropy
# 0.3326296806335449
# 0.041226564991961014
# 11
# [15, 10, 1.0] single hidden layer plus quadratic
# 0.3186311721801758
# 0.1639517339066086
# 11
# [15, 10, 1.0] dual hidden layers plus cross-entropy
# 0.49465203285217285
# 0.10810663611580823
# 47
# [15, 10, 1.0] dual hidden layers plus quadratic
# 0.49440693855285645
# 0.12413318315531613
# 12
# [15, 10, 3.0] single hidden layer plus cross-entropy
# 0.328202486038208
# 0.23396899520772715
# 96
# [15, 10, 3.0] single hidden layer plus quadratic
# 0.3302185535430908
# 0.15551424656641538
# 59
# [15, 10, 3.0] dual hidden layers plus cross-entropy
# 0.48612022399902344
# 0.06315987574941517
# 21
# [15, 10, 3.0] dual hidden layers plus quadratic
# 0.562593936920166
# 0.14379602968616823
# 66
# [15, 10, 5.0] single hidden layer plus cross-entropy
# 0.26298952102661133
# 0.3335714780020511
# 92
# [15, 10, 5.0] single hidden layer plus quadratic
# 0.31111669540405273
# 0.15357896341427865
# 11
# [15, 10, 5.0] dual hidden layers plus cross-entropy
# 0.4414939880371094
# 0.2899364558355978
# 40
# [15, 10, 5.0] dual hidden layers plus quadratic
# 0.5268850326538086
# 0.10828949391032026
# 59
# [15, 20, 0.1] single hidden layer plus cross-entropy
# 0.6740615367889404
# 0.11625923802280354
# 99
# [15, 20, 0.1] single hidden layer plus quadratic
# 0.6816856861114502
# 0.17600214787156884
# 48
# [15, 20, 0.1] dual hidden layers plus cross-entropy
# 1.1680243015289307
# 0.13335858261952552
# 48
# [15, 20, 0.1] dual hidden layers plus quadratic
# 0.5502581596374512
# 0.21285119037883882
# 25
# [15, 20, 0.5] single hidden layer plus cross-entropy
# 0.26062536239624023
# 0.11747368276597303
# 11
# [15, 20, 0.5] single hidden layer plus quadratic
# 0.31536412239074707
# 0.15187119541200547
# 18
# [15, 20, 0.5] dual hidden layers plus cross-entropy
# 0.9969027042388916
# 0.13815151514220053
# 27
# [15, 20, 0.5] dual hidden layers plus quadratic
# 0.9116847515106201
# 0.13313161696032874
# 25
# [15, 20, 1.0] single hidden layer plus cross-entropy
# 0.2632565498352051
# 0.08112559189363139
# 23
# [15, 20, 1.0] single hidden layer plus quadratic
# 0.6014583110809326
# 0.17413367501117918
# 20
# [15, 20, 1.0] dual hidden layers plus cross-entropy
# 1.402665615081787
# 0.10293173500565754
# 11
# [15, 20, 1.0] dual hidden layers plus quadratic
# 1.6610946655273438
# 0.13112829847673751
# 48
# [15, 20, 3.0] single hidden layer plus cross-entropy
# 0.29143834114074707
# 0.10916167848557537
# 47
# [15, 20, 3.0] single hidden layer plus quadratic
# 0.5662539005279541
# 0.13532905894795283
# 35
# [15, 20, 3.0] dual hidden layers plus cross-entropy
# 1.0295708179473877
# 0.09539645018856158
# 43
# [15, 20, 3.0] dual hidden layers plus quadratic
# 2.015366554260254
# 0.1512494307485098
# 90
# [15, 20, 5.0] single hidden layer plus cross-entropy
# 0.8874919414520264
# 0.12477873021452804
# 97
# [15, 20, 5.0] single hidden layer plus quadratic
# 0.44246697425842285
# 0.23162786104422037
# 59
# [15, 20, 5.0] dual hidden layers plus cross-entropy
# 1.3571043014526367
# 0.1136777616318169
# 84
# [15, 20, 5.0] dual hidden layers plus quadratic
# 0.4804649353027344
# 0.15884656435799993
# 0
# [15, 100, 0.1] single hidden layer plus cross-entropy
# 0.2758619785308838
# 0.14066485986352317
# 95
# [15, 100, 0.1] single hidden layer plus quadratic
# 0.27437400817871094
# 0.8063385747106596
# 25
# [15, 100, 0.1] dual hidden layers plus cross-entropy
# 0.460827112197876
# 0.1812670522335629
# 25
# [15, 100, 0.1] dual hidden layers plus quadratic
# 0.46420860290527344
# 0.5243423121491353
# 3
# [15, 100, 0.5] single hidden layer plus cross-entropy
# 0.29286885261535645
# 0.12062723964730564
# 79
# [15, 100, 0.5] single hidden layer plus quadratic
# 0.3477745056152344
# 0.1769141927058778
# 95
# [15, 100, 0.5] dual hidden layers plus cross-entropy
# 0.4462308883666992
# 0.1302987450679822
# 48
# [15, 100, 0.5] dual hidden layers plus quadratic
# 0.47565722465515137
# 0.16466771030862906
# 93
# [15, 100, 1.0] single hidden layer plus cross-entropy
# 0.6143479347229004
# 0.13213062566680914
# 79
# [15, 100, 1.0] single hidden layer plus quadratic
# 0.6880707740783691
# 0.1484464696697641
# 82
# [15, 100, 1.0] dual hidden layers plus cross-entropy
# 1.0596411228179932
# 0.13517375064863157
# 88
# [15, 100, 1.0] dual hidden layers plus quadratic
# 0.4632375240325928
# 0.14135793716681835
# 25
# [15, 100, 3.0] single hidden layer plus cross-entropy
# 0.29408955574035645
# 0.17099837417126307
# 59
# [15, 100, 3.0] single hidden layer plus quadratic
# 0.34018540382385254
# 0.14055388206207903
# 68
# [15, 100, 3.0] dual hidden layers plus cross-entropy
# 0.9773025512695312
# 0.1353122266797502
# 10
# [15, 100, 3.0] dual hidden layers plus quadratic
# 1.2901124954223633
# 0.13869156607931274
# 48
# [15, 100, 5.0] single hidden layer plus cross-entropy
# 0.32785749435424805
# 0.056523900044771674
# 89
# [15, 100, 5.0] single hidden layer plus quadratic
# 0.30057430267333984
# 0.15676207704508185
# 7
# [15, 100, 5.0] dual hidden layers plus cross-entropy
# 0.5402743816375732
# 0.14447742251390314
# 47
# [15, 100, 5.0] dual hidden layers plus quadratic
# 0.49399709701538086
# 0.13463429559845358
# 35
# [30, 5, 0.1] single hidden layer plus cross-entropy
# 0.5394284725189209
# 0.1355751734410564
# 23
# [30, 5, 0.1] single hidden layer plus quadratic
# 0.5922908782958984
# 0.14234519247274074
# 75
# [30, 5, 0.1] dual hidden layers plus cross-entropy
# 1.4611101150512695
# 0.10843617839385304
# 65
# [30, 5, 0.1] dual hidden layers plus quadratic
# 2.6713368892669678
# 0.13114175469517203
# 36
# [30, 5, 0.5] single hidden layer plus cross-entropy
# 0.5365302562713623
# 0.02668374685824438
# 11
# [30, 5, 0.5] single hidden layer plus quadratic
# 0.5752182006835938
# 0.14265808369103436
# 11
# [30, 5, 0.5] dual hidden layers plus cross-entropy
# 0.9614920616149902
# 0.024518897801225226
# 97
# [30, 5, 0.5] dual hidden layers plus quadratic
# 0.9632306098937988
# 0.14246679795709807
# 20
# [30, 5, 1.0] single hidden layer plus cross-entropy
# 0.5424690246582031
# 0.05002636154170167
# 84
# [30, 5, 1.0] single hidden layer plus quadratic
# 0.6475746631622314
# 0.14361217329968515
# 8
# [30, 5, 1.0] dual hidden layers plus cross-entropy
# 0.9972207546234131
# 0.05257088786709015
# 87
# [30, 5, 1.0] dual hidden layers plus quadratic
# 1.0503530502319336
# 0.1426510273476472
# 43
# [30, 5, 3.0] single hidden layer plus cross-entropy
# 0.6498005390167236
# 0.06468252996919861
# 59
# [30, 5, 3.0] single hidden layer plus quadratic
# 0.6816763877868652
# 0.09517483240231644
# 11
# [30, 5, 3.0] dual hidden layers plus cross-entropy
# 1.901977777481079
# 0.08738762233229076
# 82
# [30, 5, 3.0] dual hidden layers plus quadratic
# 2.0729880332946777
# 0.12917650284200125
# 43
# [30, 5, 5.0] single hidden layer plus cross-entropy
# 0.6205155849456787
# 0.3789316505101251
# 18
# [30, 5, 5.0] single hidden layer plus quadratic
# 0.6400136947631836
# 0.13810925045451272
# 22
# [30, 5, 5.0] dual hidden layers plus cross-entropy
# 0.9965133666992188
# 0.23641953624390136
# 93
# [30, 5, 5.0] dual hidden layers plus quadratic
# 0.9906082153320312
# 0.13401784228111002
# 97
# [30, 10, 0.1] single hidden layer plus cross-entropy
# 0.5491986274719238
# 0.14265306021140925
# 11
# [30, 10, 0.1] single hidden layer plus quadratic
# 0.558690071105957
# 0.14753221921495452
# 64
# [30, 10, 0.1] dual hidden layers plus cross-entropy
# 0.9414138793945312
# 0.12177819235029165
# 79
# [30, 10, 0.1] dual hidden layers plus quadratic
# 0.9786195755004883
# 0.13808337182961075
# 51
# [30, 10, 0.5] single hidden layer plus cross-entropy
# 0.49509572982788086
# 0.13623165492763634
# 66
# [30, 10, 0.5] single hidden layer plus quadratic
# 0.589740514755249
# 0.17065835803943075
# 11
# [30, 10, 0.5] dual hidden layers plus cross-entropy
# 1.8663110733032227
# 0.06721767978063424
# 23
# [30, 10, 0.5] dual hidden layers plus quadratic
# 1.8795130252838135
# 0.1319970709738421
# 56
# [30, 10, 1.0] single hidden layer plus cross-entropy
# 0.6051182746887207
# 0.0561752189672116
# 59
# [30, 10, 1.0] single hidden layer plus quadratic
# 0.6189694404602051
# 0.15343766033203862
# 59
# [30, 10, 1.0] dual hidden layers plus cross-entropy
# 0.9570481777191162
# 0.036586148475258366
# 64
# [30, 10, 1.0] dual hidden layers plus quadratic
# 1.0352613925933838
# 0.12999435228558678
# 67
# [30, 10, 3.0] single hidden layer plus cross-entropy
# 0.5852313041687012
# 0.1663993179990638
# 58
# [30, 10, 3.0] single hidden layer plus quadratic
# 0.645660400390625
# 0.09596847011626555
# 11
# [30, 10, 3.0] dual hidden layers plus cross-entropy
# 0.9099161624908447
# 0.07939584149538022
# 64
# [30, 10, 3.0] dual hidden layers plus quadratic
# 1.0080738067626953
# 0.14841975832374077
# 38
# [30, 10, 5.0] single hidden layer plus cross-entropy
# 0.536257266998291
# 0.19552098921254424
# 96
# [30, 10, 5.0] single hidden layer plus quadratic
# 0.562859296798706
# 0.163099447459367
# 44
# [30, 10, 5.0] dual hidden layers plus cross-entropy
# 2.1505279541015625
# 0.09919613361047756
# 96
# [30, 10, 5.0] dual hidden layers plus quadratic
# 2.2038254737854004
# 0.05698548313919723
# 43
# [30, 20, 0.1] single hidden layer plus cross-entropy
# 1.2356956005096436
# 0.12149242897537041
# 23
# [30, 20, 0.1] single hidden layer plus quadratic
# 0.5801820755004883
# 0.5058014162808963
# 25
# [30, 20, 0.1] dual hidden layers plus cross-entropy
# 0.9143562316894531
# 0.13140474666577362
# 79
# [30, 20, 0.1] dual hidden layers plus quadratic
# 0.9851288795471191
# 0.1544550093133025
# 90
# [30, 20, 0.5] single hidden layer plus cross-entropy
# 0.5478096008300781
# 0.0710067302494445
# 11
# [30, 20, 0.5] single hidden layer plus quadratic
# 0.655658483505249
# 0.16280220907213594
# 82
# [30, 20, 0.5] dual hidden layers plus cross-entropy
# 0.9908585548400879
# 0.10360733122312903
# 65
# [30, 20, 0.5] dual hidden layers plus quadratic
# 1.0524296760559082
# 0.13568752269211837
# 48
# [30, 20, 1.0] single hidden layer plus cross-entropy
# 0.6220324039459229
# 0.11288945191060255
# 59
# [30, 20, 1.0] single hidden layer plus quadratic
# 1.3452308177947998
# 0.15813724061932302
# 61
# [30, 20, 1.0] dual hidden layers plus cross-entropy
# 1.8911480903625488
# 0.08394722639013162
# 11
# [30, 20, 1.0] dual hidden layers plus quadratic
# 1.9557299613952637
# 0.1359343311942021
# 95
# [30, 20, 3.0] single hidden layer plus cross-entropy
# 0.5265974998474121
# 0.04841633744357753
# 66
# [30, 20, 3.0] single hidden layer plus quadratic
# 0.6250739097595215
# 0.12257486520212599
# 63
# [30, 20, 3.0] dual hidden layers plus cross-entropy
# 0.8719851970672607
# 0.06486447128765734
# 35
# [30, 20, 3.0] dual hidden layers plus quadratic
# 2.1872646808624268
# 0.14264220846988057
# 79
# [30, 20, 5.0] single hidden layer plus cross-entropy
# 0.6447434425354004
# 0.20041261845963004
# 94
# [30, 20, 5.0] single hidden layer plus quadratic
# 0.6142747402191162
# 0.09342928794620899
# 11
# [30, 20, 5.0] dual hidden layers plus cross-entropy
# 1.3392856121063232
# 0.15568561688309912
# 66
# [30, 20, 5.0] dual hidden layers plus quadratic
# 2.2588613033294678
# 0.14708618643019683
# 63
# [30, 100, 0.1] single hidden layer plus cross-entropy
# 0.6043484210968018
# 0.11885791497738027
# 93
# [30, 100, 0.1] single hidden layer plus quadratic
# 0.6080422401428223
# 0.28025321782196727
# 95
# [30, 100, 0.1] dual hidden layers plus cross-entropy
# 0.8850736618041992
# 0.1480397494390456
# 93
# [30, 100, 0.1] dual hidden layers plus quadratic
# 1.007629632949829
# 0.42444996918571476
# 25
# [30, 100, 0.5] single hidden layer plus cross-entropy
# 0.5586709976196289
# 0.13178095066482035
# 82
# [30, 100, 0.5] single hidden layer plus quadratic
# 0.7356104850769043
# 0.12867298359811827
# 51
# [30, 100, 0.5] dual hidden layers plus cross-entropy
# 1.0027117729187012
# 0.1349520176088706
# 91
# [30, 100, 0.5] dual hidden layers plus quadratic
# 0.9577128887176514
# 0.14699084147584546
# 85
# [30, 100, 1.0] single hidden layer plus cross-entropy
# 0.5063354969024658
# 0.1425011702181347
# 63
# [30, 100, 1.0] single hidden layer plus quadratic
# 0.5478565692901611
# 0.1507136891492867
# 61
# [30, 100, 1.0] dual hidden layers plus cross-entropy
# 1.7217719554901123
# 0.13756762004124795
# 16
# [30, 100, 1.0] dual hidden layers plus quadratic
# 1.988832712173462
# 0.13802558690124497
# 85
# [30, 100, 3.0] single hidden layer plus cross-entropy
# 0.5266580581665039
# 0.11283224368536901
# 45
# [30, 100, 3.0] single hidden layer plus quadratic
# 0.6069827079772949
# 0.152148226700353
# 82
# [30, 100, 3.0] dual hidden layers plus cross-entropy
# 0.9106462001800537
# 0.13376609117875363
# 51
# [30, 100, 3.0] dual hidden layers plus quadratic
# 0.9817671775817871
# 0.13695485623048562
# 6
# [30, 100, 5.0] single hidden layer plus cross-entropy
# 0.6173224449157715
# 0.12184215069689168
# 69
# [30, 100, 5.0] single hidden layer plus quadratic
# 0.6344859600067139
# 0.17010940850642303
# 64
# [30, 100, 5.0] dual hidden layers plus cross-entropy
# 0.9684774875640869
# 0.13861592711822376
# 40
# [30, 100, 5.0] dual hidden layers plus quadratic
# 1.028594970703125
# 0.14473413801023222
# 32
# [45, 5, 0.1] single hidden layer plus cross-entropy
# 0.8806552886962891
# 0.10387622686849317
# 11
# [45, 5, 0.1] single hidden layer plus quadratic
# 1.4469881057739258
# 0.16525697096953285
# 35
# [45, 5, 0.1] dual hidden layers plus cross-entropy
# 2.6755948066711426
# 0.1255239859348417
# 63
# [45, 5, 0.1] dual hidden layers plus quadratic
# 1.4925634860992432
# 0.12887610492203194
# 48
# [45, 5, 0.5] single hidden layer plus cross-entropy
# 0.8425631523132324
# 0.024274175015775418
# 8
# [45, 5, 0.5] single hidden layer plus quadratic
# 0.9156136512756348
# 0.13016270488083892
# 11
# [45, 5, 0.5] dual hidden layers plus cross-entropy
# 1.402632474899292
# 0.11541031305303706
# 35
# [45, 5, 0.5] dual hidden layers plus quadratic
# 1.475477695465088
# 0.13094255442503502
# 59
# [45, 5, 1.0] single hidden layer plus cross-entropy
# 0.8274679183959961
# 0.052421003367484786
# 59
# [45, 5, 1.0] single hidden layer plus quadratic
# 0.9173805713653564
# 0.153656721348153
# 11
# [45, 5, 1.0] dual hidden layers plus cross-entropy
# 3.100940227508545
# 0.04978482865694953
# 8
# [45, 5, 1.0] dual hidden layers plus quadratic
# 1.7696008682250977
# 0.13890775666955862
# 59
# [45, 5, 3.0] single hidden layer plus cross-entropy
# 0.8548321723937988
# 0.033220708935624135
# 96
# [45, 5, 3.0] single hidden layer plus quadratic
# 1.0477404594421387
# 0.13166670109795292
# 34
# [45, 5, 3.0] dual hidden layers plus cross-entropy
# 1.5167531967163086
# 0.13140862552151505
# 96
# [45, 5, 3.0] dual hidden layers plus quadratic
# 1.5153539180755615
# 0.05906109241246755
# 87
# [45, 5, 5.0] single hidden layer plus cross-entropy
# 0.7833826541900635
# 0.40700972619272874
# 60
# [45, 5, 5.0] single hidden layer plus quadratic
# 0.9256584644317627
# 0.1335772684111466
# 34
# [45, 5, 5.0] dual hidden layers plus cross-entropy
# 2.458650827407837
# 0.2912988229453573
# 10
# [45, 5, 5.0] dual hidden layers plus quadratic
# 2.2382609844207764
# 0.05901339621027842
# 87
# [45, 10, 0.1] single hidden layer plus cross-entropy
# 0.828580379486084
# 0.11146330365242776
# 11
# [45, 10, 0.1] single hidden layer plus quadratic
# 0.8805687427520752
# 0.14147969733116728
# 64
# [45, 10, 0.1] dual hidden layers plus cross-entropy
# 1.3815653324127197
# 0.11565347098352477
# 17
# [45, 10, 0.1] dual hidden layers plus quadratic
# 1.5516657829284668
# 0.13726779335448877
# 45
# [45, 10, 0.5] single hidden layer plus cross-entropy
# 0.8069872856140137
# 0.06351258984103786
# 11
# [45, 10, 0.5] single hidden layer plus quadratic
# 0.9782466888427734
# 0.12327863346596483
# 11
# [45, 10, 0.5] dual hidden layers plus cross-entropy
# 1.7071599960327148
# 0.09792538622896839
# 87
# [45, 10, 0.5] dual hidden layers plus quadratic
# 3.257014036178589
# 0.14358060426860525
# 64
# [45, 10, 1.0] single hidden layer plus cross-entropy
# 0.7957439422607422
# 0.016945532432039646
# 59
# [45, 10, 1.0] single hidden layer plus quadratic
# 0.8886406421661377
# 0.1842842198929362
# 59
# [45, 10, 1.0] dual hidden layers plus cross-entropy
# 1.3994576930999756
# 0.03163513134829444
# 53
# [45, 10, 1.0] dual hidden layers plus quadratic
# 1.4616520404815674
# 0.1498279761052545
# 60
# [45, 10, 3.0] single hidden layer plus cross-entropy
# 0.776139497756958
# 0.1220918831259385
# 44
# [45, 10, 3.0] single hidden layer plus quadratic
# 0.9203553199768066
# 0.17592447511292703
# 44
# [45, 10, 3.0] dual hidden layers plus cross-entropy
# 1.4347600936889648
# 0.031216637820684803
# 97
# [45, 10, 3.0] dual hidden layers plus quadratic
# 2.872922897338867
# 0.16422803660366506
# 63
# [45, 10, 5.0] single hidden layer plus cross-entropy
# 1.0988423824310303
# 0.15985404186277416
# 45
# [45, 10, 5.0] single hidden layer plus quadratic
# 0.9332613945007324
# 0.08576850465182935
# 84
# [45, 10, 5.0] dual hidden layers plus cross-entropy
# 1.4225451946258545
# 0.26575534823598684
# 35
# [45, 10, 5.0] dual hidden layers plus quadratic
# 1.5139095783233643
# 0.118091094319888
# 47
# [45, 20, 0.1] single hidden layer plus cross-entropy
# 0.7428741455078125
# 0.1131748792924374
# 11
# [45, 20, 0.1] single hidden layer plus quadratic
# 0.8272006511688232
# 0.11660934533760621
# 79
# [45, 20, 0.1] dual hidden layers plus cross-entropy
# 1.3115043640136719
# 0.13365558118331222
# 48
# [45, 20, 0.1] dual hidden layers plus quadratic
# 1.4196221828460693
# 0.13216762246819294
# 79
# [45, 20, 0.5] single hidden layer plus cross-entropy
# 1.6814312934875488
# 0.06288889817538476
# 59
# [45, 20, 0.5] single hidden layer plus quadratic
# 1.4953811168670654
# 0.15696342517521683
# 47
# [45, 20, 0.5] dual hidden layers plus cross-entropy
# 1.407228946685791
# 0.07466250821217911
# 84
# [45, 20, 0.5] dual hidden layers plus quadratic
# 1.6485357284545898
# 0.1399955932594229
# 48
# [45, 20, 1.0] single hidden layer plus cross-entropy
# 0.7792000770568848
# 0.06794197628486183
# 11
# [45, 20, 1.0] single hidden layer plus quadratic
# 0.9512939453125
# 0.14697898901156975
# 82
# [45, 20, 1.0] dual hidden layers plus cross-entropy
# 1.4165053367614746
# 0.11484282372188366
# 84
# [45, 20, 1.0] dual hidden layers plus quadratic
# 1.5349419116973877
# 0.1387963044609444
# 33
# [45, 20, 3.0] single hidden layer plus cross-entropy
# 1.4951403141021729
# 0.06992081525554163
# 44
# [45, 20, 3.0] single hidden layer plus quadratic
# 2.0759215354919434
# 0.16251323187748123
# 23
# [45, 20, 3.0] dual hidden layers plus cross-entropy
# 1.3117256164550781
# 0.08145962783658531
# 23
# [45, 20, 3.0] dual hidden layers plus quadratic
# 1.4213345050811768
# 0.14804098985601544
# 11
# [45, 20, 5.0] single hidden layer plus cross-entropy
# 0.7657837867736816
# 0.09261132571149108
# 29
# [45, 20, 5.0] single hidden layer plus quadratic
# 0.8681304454803467
# 0.08614294743983018
# 8
# [45, 20, 5.0] dual hidden layers plus cross-entropy
# 1.3348777294158936
# 0.07807428301439734
# 46
# [45, 20, 5.0] dual hidden layers plus quadratic
# 1.4996614456176758
# 0.14726435191357706
# 97
# [45, 100, 0.1] single hidden layer plus cross-entropy
# 0.7735612392425537
# 0.1135359621325448
# 95
# [45, 100, 0.1] single hidden layer plus quadratic
# 1.4940457344055176
# 0.20961390565322616
# 68
# [45, 100, 0.1] dual hidden layers plus cross-entropy
# 2.602684259414673
# 0.1343905016946304
# 93
# [45, 100, 0.1] dual hidden layers plus quadratic
# 1.48612642288208
# 0.2427218915939074
# 9
# [45, 100, 0.5] single hidden layer plus cross-entropy
# 0.7918527126312256
# 0.1254474509622357
# 61
# [45, 100, 0.5] single hidden layer plus quadratic
# 0.9912748336791992
# 0.13768085774849245
# 95
# [45, 100, 0.5] dual hidden layers plus cross-entropy
# 1.289552927017212
# 0.1277967157481114
# 48
# [45, 100, 0.5] dual hidden layers plus quadratic
# 1.450080394744873
# 0.13748356825560634
# 95
# [45, 100, 1.0] single hidden layer plus cross-entropy
# 0.7444009780883789
# 0.12104931327601305
# 43
# [45, 100, 1.0] single hidden layer plus quadratic
# 0.8913624286651611
# 0.1497334335705989
# 64
# [45, 100, 1.0] dual hidden layers plus cross-entropy
# 2.3320608139038086
# 0.1239070735663525
# 12
# [45, 100, 1.0] dual hidden layers plus quadratic
# 1.9869847297668457
# 0.1357216038868773
# 85
# [45, 100, 3.0] single hidden layer plus cross-entropy
# 0.8506298065185547
# 0.07924417672687395
# 26
# [45, 100, 3.0] single hidden layer plus quadratic
# 0.9647448062896729
# 0.16666013588945383
# 86
# [45, 100, 3.0] dual hidden layers plus cross-entropy
# 1.3799223899841309
# 0.10616640198532436
# 43
# [45, 100, 3.0] dual hidden layers plus quadratic
# 1.4750473499298096
# 0.13795298333003908
# 55
# [45, 100, 5.0] single hidden layer plus cross-entropy
# 0.8243842124938965
# 0.058943521793872376
# 35
# [45, 100, 5.0] single hidden layer plus quadratic
# 0.8918476104736328
# 0.15089126543031306
# 11
# [45, 100, 5.0] dual hidden layers plus cross-entropy
# 1.6274433135986328
# 0.13692237537620874
# 51
# [45, 100, 5.0] dual hidden layers plus quadratic
# 2.925048589706421
# 0.15585651802614756
# 36
# [100, 5, 0.1] single hidden layer plus cross-entropy
# 1.7333579063415527
# 0.05433113110694073
# 59
# [100, 5, 0.1] single hidden layer plus quadratic
# 1.9254002571105957
# 0.1510524504095888
# 11
# [100, 5, 0.1] dual hidden layers plus cross-entropy
# 2.986565113067627
# 0.11472569567297014
# 64
# [100, 5, 0.1] dual hidden layers plus quadratic
# 4.255009174346924
# 0.1409515653063565
# 81
# [100, 5, 0.5] single hidden layer plus cross-entropy
# 2.4750730991363525
# 0.034889078859837386
# 34
# [100, 5, 0.5] single hidden layer plus quadratic
# 1.9701013565063477
# 0.12247019663934865
# 11
# [100, 5, 0.5] dual hidden layers plus cross-entropy
# 3.029402494430542
# 0.07991353774927482
# 38
# [100, 5, 0.5] dual hidden layers plus quadratic
# 3.2112228870391846
# 0.12894224732320161
# 43
# [100, 5, 1.0] single hidden layer plus cross-entropy
# 3.3200488090515137
# 0.0230705337369728
# 47
# [100, 5, 1.0] single hidden layer plus quadratic
# 2.0063815116882324
# 0.10685433762195579
# 59
# [100, 5, 1.0] dual hidden layers plus cross-entropy
# 3.328465461730957
# 0.06809661332937322
# 53
# [100, 5, 1.0] dual hidden layers plus quadratic
# 3.2887370586395264
# 0.09198583587224603
# 53
# [100, 5, 3.0] single hidden layer plus cross-entropy
# 3.9552977085113525
# 0.0698838608929079
# 47
# [100, 5, 3.0] single hidden layer plus quadratic
# 2.077674388885498
# 0.09007475038873491
# 44
# [100, 5, 3.0] dual hidden layers plus cross-entropy
# 3.1771371364593506
# 0.034050729496907774
# 96
# [100, 5, 3.0] dual hidden layers plus quadratic
# 3.4442336559295654
# 0.060028290412615114
# 97
# [100, 5, 5.0] single hidden layer plus cross-entropy
# 3.584549903869629
# 0.030502324362625653
# 31
# [100, 5, 5.0] single hidden layer plus quadratic
# 2.023395299911499
# 0.015412706976048776
# 11
# [100, 5, 5.0] dual hidden layers plus cross-entropy
# 2.9296956062316895
# 0.360342842482989
# 10
# [100, 5, 5.0] dual hidden layers plus quadratic
# 3.2520642280578613
# 0.09156392667647953
# 87
# [100, 10, 0.1] single hidden layer plus cross-entropy
# 2.329227924346924
# 0.058353692796861936
# 59
# [100, 10, 0.1] single hidden layer plus quadratic
# 3.156050205230713
# 0.15513201967196194
# 82
# [100, 10, 0.1] dual hidden layers plus cross-entropy
# 3.061669111251831
# 0.08573557536560822
# 11
# [100, 10, 0.1] dual hidden layers plus quadratic
# 3.371748208999634
# 0.13991590249419464
# 73
# [100, 10, 0.5] single hidden layer plus cross-entropy
# 1.7298972606658936
# 0.03496913562226005
# 47
# [100, 10, 0.5] single hidden layer plus quadratic
# 3.8934214115142822
# 0.14705516818325365
# 34
# [100, 10, 0.5] dual hidden layers plus cross-entropy
# 2.913991928100586
# 0.015977645700176325
# 23
# [100, 10, 0.5] dual hidden layers plus quadratic
# 3.150804042816162
# 0.15042096292242935
# 35
# [100, 10, 1.0] single hidden layer plus cross-entropy
# 1.8285672664642334
# 0.04656218362139957
# 23
# [100, 10, 1.0] single hidden layer plus quadratic
# 3.778517246246338
# 0.12614888913802255
# 44
# [100, 10, 1.0] dual hidden layers plus cross-entropy
# 3.1257519721984863
# 0.07195691050256076
# 22
# [100, 10, 1.0] dual hidden layers plus quadratic
# 3.223327875137329
# 0.12279453810427737
# 43
# [100, 10, 3.0] single hidden layer plus cross-entropy
# 1.8106558322906494
# 0.016712667218589723
# 96
# [100, 10, 3.0] single hidden layer plus quadratic
# 2.642941951751709
# 0.06729923402269893
# 59
# [100, 10, 3.0] dual hidden layers plus cross-entropy
# 4.13111138343811
# 0.026724497094243
# 66
# [100, 10, 3.0] dual hidden layers plus quadratic
# 3.3377625942230225
# 0.17714186945940538
# 59
# [100, 10, 5.0] single hidden layer plus cross-entropy
# 2.4118404388427734
# 0.14215390263679015
# 44
# [100, 10, 5.0] single hidden layer plus quadratic
# 8.829032897949219
# 0.08792106095636544
# 59
# [100, 10, 5.0] dual hidden layers plus cross-entropy
# 3.1227056980133057
# 0.10922926974402267
# 11
# [100, 10, 5.0] dual hidden layers plus quadratic
# 3.374406337738037
# 0.084738502280697
# 11
# [100, 20, 0.1] single hidden layer plus cross-entropy
# 3.619765043258667
# 0.08096432553336234
# 11
# [100, 20, 0.1] single hidden layer plus quadratic
# 2.258974552154541
# 0.13526020240118583
# 73
# [100, 20, 0.1] dual hidden layers plus cross-entropy
# 3.119002342224121
# 0.12064453791734661
# 65
# [100, 20, 0.1] dual hidden layers plus quadratic
# 3.6616692543029785
# 0.13623521403287137
# 25
# [100, 20, 0.5] single hidden layer plus cross-entropy
# 5.731358051300049
# 0.040399133623095176
# 11
# [100, 20, 0.5] single hidden layer plus quadratic
# 2.9003348350524902
# 0.11233962785606387
# 82
# [100, 20, 0.5] dual hidden layers plus cross-entropy
# 3.2513668537139893
# 0.041815452455884854
# 44
# [100, 20, 0.5] dual hidden layers plus quadratic
# 3.205883502960205
# 0.14241069302763085
# 12
# [100, 20, 1.0] single hidden layer plus cross-entropy
# 3.4200525283813477
# 0.06813814497010705
# 34
# [100, 20, 1.0] single hidden layer plus quadratic
# 1.9524338245391846
# 0.11929095504100538
# 66
# [100, 20, 1.0] dual hidden layers plus cross-entropy
# 3.047504425048828
# 0.039442747799232555
# 87
# [100, 20, 1.0] dual hidden layers plus quadratic
# 3.209867477416992
# 0.15750548374815826
# 24
# [100, 20, 3.0] single hidden layer plus cross-entropy
# 2.9085259437561035
# 0.06057551079552764
# 47
# [100, 20, 3.0] single hidden layer plus quadratic
# 2.4359326362609863
# 0.09279330551714918
# 34
# [100, 20, 3.0] dual hidden layers plus cross-entropy
# 2.9393744468688965
# 0.07084056887621559
# 66
# [100, 20, 3.0] dual hidden layers plus quadratic
# 3.160963296890259
# 0.12336762719786042
# 97
# [100, 20, 5.0] single hidden layer plus cross-entropy
# 1.8888099193572998
# 0.05067158951605268
# 46
# [100, 20, 5.0] single hidden layer plus quadratic
# 3.9080941677093506
# 0.05156278257810599
# 84
# [100, 20, 5.0] dual hidden layers plus cross-entropy
# 3.253899097442627
# 0.019619174957383897
# 15
# [100, 20, 5.0] dual hidden layers plus quadratic
# 3.2576444149017334
# 0.1401116322194969
# 22
# [100, 100, 0.1] single hidden layer plus cross-entropy
# 1.6416573524475098
# 0.13857363563202604
# 73
# [100, 100, 0.1] single hidden layer plus quadratic
# 3.755221366882324
# 0.15164565740610345
# 79
# [100, 100, 0.1] dual hidden layers plus cross-entropy
# 3.7982194423675537
# 0.12964509905874577
# 25
# [100, 100, 0.1] dual hidden layers plus quadratic
# 3.3947014808654785
# 0.1599709753104823
# 28
# [100, 100, 0.5] single hidden layer plus cross-entropy
# 1.9122745990753174
# 0.12057894454596915
# 59
# [100, 100, 0.5] single hidden layer plus quadratic
# 4.090003967285156
# 0.12930201187969148
# 48
# [100, 100, 0.5] dual hidden layers plus cross-entropy
# 2.917630195617676
# 0.11858583800283978
# 88
# [100, 100, 0.5] dual hidden layers plus quadratic
# 3.1764795780181885
# 0.13716585985887259
# 51
# [100, 100, 1.0] single hidden layer plus cross-entropy
# 1.8987054824829102
# 0.07981058820302918
# 84
# [100, 100, 1.0] single hidden layer plus quadratic
# 3.649273633956909
# 0.15441100039751013
# 79
# [100, 100, 1.0] dual hidden layers plus cross-entropy
# 3.192486047744751
# 0.11327331038348552
# 65
# [100, 100, 1.0] dual hidden layers plus quadratic
# 3.155088424682617
# 0.13685965127413707
# 25
# [100, 100, 3.0] single hidden layer plus cross-entropy
# 1.659280776977539
# 0.04737385817784647
# 62
# [100, 100, 3.0] single hidden layer plus quadratic
# 2.2455806732177734
# 0.15263635278846363
# 59
# [100, 100, 3.0] dual hidden layers plus cross-entropy
# 4.655555009841919
# 0.07886539789034543
# 11
# [100, 100, 3.0] dual hidden layers plus quadratic
# 3.4795100688934326
# 0.15663443774394026
# 85
# [100, 100, 5.0] single hidden layer plus cross-entropy
# 1.7704143524169922
# 0.1325374638495456
# 46
# [100, 100, 5.0] single hidden layer plus quadratic
# 2.010728597640991
# 0.17306795474556372
# 11
# [100, 100, 5.0] dual hidden layers plus cross-entropy
# 4.977142572402954
# 0.13965534639283778
# 59
# [100, 100, 5.0] dual hidden layers plus quadratic
# 3.0442633628845215
# 0.14367173970429933
# 50

# %%
import matplotlib.pyplot as plt

# pre-process our really janked up data ... first the training_times
training_timesSingle1 = training_times[0::4]
training_timesSingle2 = training_times[1::4]
training_timesDouble1 = training_times[2::4]
training_timesDouble2 = training_times[3::4]
training_timesSingle = []
training_timesDouble = []
for tt1, tt2 in zip(training_timesSingle1, training_timesSingle2):
    training_timesSingle.append(tt1)
    training_timesSingle.append(tt2)
for tt1, tt2 in zip(training_timesDouble1, training_timesDouble2):
    training_timesDouble.append(tt1)
    training_timesDouble.append(tt2)

# and now the accuracies...
accuraciesSingle1 = accuracies[0::4]
accuraciesSingle2 = accuracies[1::4]
accuraciesDouble1 = accuracies[2::4]
accuraciesDouble2 = accuracies[3::4]
accuraciesSingle = []
accuraciesDouble = []
for acc1, acc2 in zip(accuraciesSingle1, accuraciesSingle2):
    accuraciesSingle.append(acc1[1][-1])
    accuraciesSingle.append(acc2[1][-1])
for acc1, acc2 in zip(accuraciesDouble1, accuraciesDouble2):
    accuraciesDouble.append(acc1[1][-1])
    accuraciesDouble.append(acc2[1][-1])

# and now the labels
labelsSingle = []
labelsDouble = []
for config in configs:
    labelsSingle.append(f"{config}-cross-784-15-10")
    labelsSingle.append(f"{config}-quad-784-15-10")
    labelsDouble.append(f"{config}-cross-784-30-15-10")
    labelsDouble.append(f"{config}-quad-784-30-15-10")

fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsSingle, accuraciesSingle)
plt.show()
fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsDouble, training_timesDouble)
plt.show()

# %%
# extract the "results" (training times and accuracies) for all configs where the # epochs is 30, the batch size is 10, the cost function is quadratic and the learning rate is variable
label_learningrate = []
tt_learningrate = []
acc_learningrate = []
for i, config in enumerate(configs):
  if config[0] == 30 and config[1] == 10:
    label_learningrate.append(labelsSingle[2*i])
    tt_learningrate.append(training_timesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)
    acc_learningrate.append(accuraciesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)

print(label_learningrate)
print(tt_learningrate)
print(acc_learningrate)

plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, tt_learningrate)
plt.show()
plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, acc_learningrate)
plt.show
# Out:
# ['[30, 10, 0.1]-cross-784-15-10', '[30, 10, 0.5]-cross-784-15-10', '[30, 10, 1.0]-cross-784-15-10', '[30, 10, 3.0]-cross-784-15-10', '[30, 10, 5.0]-cross-784-15-10']
# [0.5491986274719238, 0.49509572982788086, 0.6051182746887207, 0.5852313041687012, 0.536257266998291]
# [70, 70, 70, 68, 27]
# <function matplotlib.pyplot.show(*args, **kw)>
